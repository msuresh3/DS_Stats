# %% [markdown]
# <a href="https://colab.research.google.com/github/msuresh3/DS_Stats/blob/main/LA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Linear Algebra**
# **Matrix Addition Exercise**

# %%
import numpy as np

# %%
arr1  = np.array([-4, 3])
arr2  = np.array([5, 3])

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
arr1 + arr2
# Out:
# array([1, 6])

# %%
print(type(arr1))
# Out:
# <class 'numpy.ndarray'>
